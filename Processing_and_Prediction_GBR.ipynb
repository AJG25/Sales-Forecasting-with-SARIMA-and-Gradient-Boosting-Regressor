# %%
import numpy as np
import pandas as pd
df1 = pd.read_csv('calendar.csv')
df2 = pd.read_csv('sample_submission.csv')
df3 = pd.read_csv('sell_prices.csv')
df4 = pd.read_csv('sales_train_validation.csv')
df5 = pd.read_csv('sales_test_validation.csv')

# %%
#Investigate price dataset
import matplotlib.pyplot as plt

itemid = 'FOODS_3_007'
filtered_df3 = df3[df3['item_id'] == itemid]

# Scatter plot of price vs time
plt.figure(figsize=(10, 6))
plt.scatter(filtered_df3['wm_yr_wk'], filtered_df3['sell_price'], marker='o')
title = 'Sell Price Over Time for '+ itemid
plt.title(title)
plt.xlabel('Time (wm_yr_wk)')
plt.ylabel('Sell Price')
plt.grid(True)
plt.show()

# %% [markdown]
# Manual inspection concludes there is no trend in price of products. Outliers are clear, may reflect promotions. Although event information is given, we chose to disregard all event information by removing outliers from sales quantity data as well.

# %%
first_row = df4.loc[3].drop(labels=['id'])
time_index = range(1, len(first_row) + 1)

#Scatter plot for food 1 sale
plt.figure(figsize=(10, 6))
plt.scatter(time_index, first_row, marker='o')
plt.title('Quantity Over Time for First Row of df4')
plt.xlabel('Time')
plt.ylabel('Quantity')
plt.grid(True)
plt.show()

# %%
#join train and test validation set, we'll use test evaluation data as validation with our first approach
df4 = pd.concat([df4,df5.iloc[:,1:]],axis=1)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import GradientBoostingRegressor

def predict_single_row_GBR(df_sale, df_cal, rowid):
    food_id = df_sale.iloc[rowid,0]
    row = df_sale.iloc[rowid,1:]
    
    # Drop all columns from the beginning where the value is 0 until the first non-zero value
    first_non_zero_index = row.ne(0).idxmax()
    filtered_sales = row[first_non_zero_index:]

    # Count the length of the days where this product existed
    num_days_existed = len(filtered_sales)

    # Select the matching rows from df1 by counting backwards from the last row - 28
    start_index = len(df_cal) - 28 - num_days_existed
    selected_calendar = df_cal.iloc[start_index:len(df_cal) - 28]

    # Create a new dataframe with the sales quantity data as a new column
    result_df = selected_calendar.copy()
    result_df['sales_quantity'] = filtered_sales.values
    result_df = result_df.drop(columns=['date','wm_yr_wk','wday','year','event_name_1','event_name_2','event_type_2'])
    
    # Convert categorical features to numerical using one-hot encoding
    categorical_features = ['weekday', 'month', 'event_type_1']
    categories = [ ['Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'], # weekday categories 
                  list(range(1, 13)), # month categories (1 to 12) 
                  result_df['event_type_1'].unique().tolist() # unique event_type_1 categories
                 ]
    encoder = OneHotEncoder(sparse=False, drop='first', categories=categories)
    encoded_features = encoder.fit_transform(result_df[categorical_features])

    # Create a new dataframe with encoded features
    encoded_df = pd.DataFrame(encoded_features, columns=encoder.get_feature_names_out(categorical_features))
    result_df = result_df.drop(columns=categorical_features).reset_index(drop=True)
    result_df = pd.concat([result_df, encoded_df], axis=1)
    
    # Split the data into training and testing sets
    X_train = result_df.drop(columns=['sales_quantity'])
    y_train = result_df['sales_quantity']

    # Build and train the model
    model = GradientBoostingRegressor()
    model.fit(X_train, y_train)
    
    # Process test data
    X_test = df_cal.tail(28).drop(columns=['date','wm_yr_wk','wday','year','event_name_1','event_name_2','event_type_2'])
    encoded_features = encoder.transform(X_test[categorical_features]) # does not fit again
    encoded_df = pd.DataFrame(encoded_features, columns=encoder.get_feature_names_out(categorical_features))
    X_test = X_test.drop(columns=categorical_features).reset_index(drop=True)
    X_test = pd.concat([X_test, encoded_df], axis=1)
    
    # Predict
    y_pred = model.predict(X_test)
    
    # Convert to integer
    y_pred = np.rint(y_pred).astype(int)
    y_pred = np.maximum(y_pred, 0)

    return food_id, y_pred

# %%
result_pred = pd.DataFrame(columns=df2.columns)

for row_id in range(len(df4)):
    food_id, pred = predict_single_row_GBR(df_sale=df4, df_cal=df1, rowid=row_id)
    series = pd.concat([pd.Series([food_id]), pd.Series(pred)], ignore_index=True)
    result_pred = pd.concat([result_pred, pd.DataFrame([series])], axis=0, ignore_index=True)
    print(str(row_id) + ' done')

# %%
result_pred = result_pred.iloc[:,29:]
result_pred.columns = df2.columns

# %%
from sklearn.metrics import mean_squared_error

df_eval = pd.read_csv('sales_test_evaluation_afcs_2024.csv')
pred_numerical = result_pred.iloc[:, 1:]
eval_numerical = df_eval.iloc[:, 1:]


# RMSE for every day
rmse_values = {}
for i in range(pred_numerical.shape[1]):
    rmse = np.sqrt(mean_squared_error(pred_numerical.iloc[:, i], eval_numerical.iloc[:, i]))
    rmse_values[i] = rmse

for column, rmse in rmse_values.items():
    print(f'RMSE for {column}: {rmse}')

total_rmse = sum(rmse_values.values())
print(f'Total RMSE: {total_rmse}')

average_rmse = total_rmse / len(rmse_values)
print(f'Average RMSE per day: {average_rmse}')
# Out:
# RMSE for 0: 3.4866522081932905
# RMSE for 1: 5.234013442791254
# RMSE for 2: 2.63424498833465
# RMSE for 3: 2.5881776265334757
# RMSE for 4: 3.394298700689411
# RMSE for 5: 4.51916399972153
# RMSE for 6: 3.3237610633615566
# RMSE for 7: 3.41535379650272
# RMSE for 8: 2.5555790349999405
# RMSE for 9: 3.534072994712511
# RMSE for 10: 3.1185565405679787
# RMSE for 11: 3.3889248537908827
# RMSE for 12: 3.157663439334817
# RMSE for 13: 4.211740807769959
# RMSE for 14: 3.7659341502874604
# RMSE for 15: 3.859784240911822
# RMSE for 16: 3.5022991927418126
# RMSE for 17: 3.5258117822963593
# RMSE for 18: 3.5316654706179067
# RMSE for 19: 4.161969811231098
# RMSE for 20: 4.872368592241706
# RMSE for 21: 4.136492606231695
# RMSE for 22: 4.508396378989436
# RMSE for 23: 4.074935984856748
# RMSE for 24: 3.669022403160918
# RMSE for 25: 4.092787717451457
# RMSE for 26: 3.902985117971334
# RMSE for 27: 4.722557743462775
# Total RMSE: 104.88921468975653
# Average RMSE per day: 3.7460433817770187

# %%
# RMSE for every item
rmse_values = {}
for i in range(pred_numerical.shape[0]):
    rmse = np.sqrt(mean_squared_error(pred_numerical.iloc[i, :], eval_numerical.iloc[i, :]))
    rmse_values[i] = rmse

for row_index, rmse in rmse_values.items():
    print(f'RMSE for food item {row_index}: {rmse}')

total_rmse = sum(rmse_values.values())
print(f'Total RMSE: {total_rmse}')

average_rmse = total_rmse / len(rmse_values)
print(f'Average RMSE per item: {average_rmse}')
# Out:
# RMSE for food item 0: 1.0690449676496976
# RMSE for food item 1: 2.0615528128088303
# RMSE for food item 2: 0.944911182523068
# RMSE for food item 3: 0.7071067811865476
# RMSE for food item 4: 1.5923926292577109
# RMSE for food item 5: 0.9063269671749657
# RMSE for food item 6: 6.777062153217383
# RMSE for food item 7: 7.794228634059948
# RMSE for food item 8: 0.9819805060619657
# RMSE for food item 9: 0.7559289460184544
# RMSE for food item 10: 1.118033988749895
# RMSE for food item 11: 1.0690449676496976
# RMSE for food item 12: 1.4015297764534702
# RMSE for food item 13: 1.3627702877384937
# RMSE for food item 14: 2.434865792722759
# RMSE for food item 15: 1.2535663410560174
# RMSE for food item 16: 0.3779644730092272
# RMSE for food item 17: 0.8864052604279183
# RMSE for food item 18: 1.6903085094570331
# RMSE for food item 19: 3.1679195516480982
# RMSE for food item 20: 2.0788046015507495
# RMSE for food item 21: 0.8864052604279183
# RMSE for food item 22: 1.2100767390069582
# RMSE for food item 23: 5.800246300189083
# RMSE for food item 24: 2.0089087300607478
# RMSE for food item 25: 1.0690449676496976
# RMSE for food item 26: 1.1019463300386794
# RMSE for food item 27: 1.0350983390135313
# RMSE for food item 28: 1.8322507626258087
# RMSE for food item 29: 11.982129550769704
# RMSE for food item 30: 0.1889822365046136
# RMSE for food item 31: 1.3363062095621219
# RMSE for food item 32: 0.6813851438692469
# RMSE for food item 33: 1.224744871391589
# RMSE for food item 34: 0.9819805060619657
# RMSE for food item 35: 0.6813851438692469
# RMSE for food item 36: 1.2100767390069582
# RMSE for food item 37: 0.5345224838248488
# RMSE for food item 38: 2.471263413143742
# RMSE for food item 39: 0.3779644730092272
# RMSE for food item 40: 1.475998451412273
# RMSE for food item 41: 3.0296157229212137
# RMSE for food item 42: 0.2672612419124244
# RMSE for food item 43: 0.8660254037844386
# RMSE for food item 44: 0.7071067811865476
# RMSE for food item 45: 0.2672612419124244
# RMSE for food item 46: 1.535298947157477
# RMSE for food item 47: 1.625686668105863
# RMSE for food item 48: 0.5345224838248488
# RMSE for food item 49: 0.9636241116594315
# RMSE for food item 50: 1.349603116263656
# RMSE for food item 51: 0.9819805060619657
# RMSE for food item 52: 2.8030595529069404
# RMSE for food item 53: 1.0177004891982149
# RMSE for food item 54: 0.8017837257372732
# RMSE for food item 55: 0.7791937224739796
# RMSE for food item 56: 1.5
# RMSE for food item 57: 1.349603116263656
# RMSE for food item 58: 1.917960226013936
# RMSE for food item 59: 0.5669467095138409
# RMSE for food item 60: 0.32732683535398854
# RMSE for food item 61: 1.1801936887041646
# RMSE for food item 62: 7.4952365825617155
# RMSE for food item 63: 1.1019463300386794
# RMSE for food item 64: 3.760699023168052
# RMSE for food item 65: 1.224744871391589
# RMSE for food item 66: 0.2672612419124244
# RMSE for food item 67: 1.9730324738475904
# RMSE for food item 68: 5.612486080160912
# RMSE for food item 69: 3.438230441873926
# RMSE for food item 70: 1.5118578920369088
# RMSE for food item 71: 3.625307868699863
# RMSE for food item 72: 1.8126539343499315
# RMSE for food item 73: 0.8864052604279183
# RMSE for food item 74: 4.3177375027735465
# RMSE for food item 75: 3.955105199973465
# RMSE for food item 76: 0.4629100498862757
# RMSE for food item 77: 2.390457218668787
# RMSE for food item 78: 5.678908345800274
# RMSE for food item 79: 0.7071067811865476
# RMSE for food item 80: 0.8864052604279183
# RMSE for food item 81: 0.8451542547285166
# RMSE for food item 82: 1.267731382092775
# RMSE for food item 83: 0.6546536707079771
# RMSE for food item 84: 12.998626301047574
# RMSE for food item 85: 3.1566256848549075
# RMSE for food item 86: 0.7071067811865476
# RMSE for food item 87: 1.6035674514745464
# RMSE for food item 88: 26.5941722939444
# RMSE for food item 89: 0.7559289460184544
# RMSE for food item 90: 0.9258200997725514
# RMSE for food item 91: 1.4142135623730951
# RMSE for food item 92: 1.0690449676496976
# RMSE for food item 93: 0.8864052604279183
# RMSE for food item 94: 0.823754471047914
# RMSE for food item 95: 2.0788046015507495
# RMSE for food item 96: 2.6049403612586386
# RMSE for food item 97: 10.033871208490341
# RMSE for food item 98: 1.6583123951777
# RMSE for food item 99: 1.475998451412273
# RMSE for food item 100: 2.2280677086403173
# RMSE for food item 101: 1.118033988749895
# RMSE for food item 102: 1.2392393980641052
# RMSE for food item 103: 0.944911182523068
# RMSE for food item 104: 2.32992949004287
# RMSE for food item 105: 1.7728105208558367
# RMSE for food item 106: 1.2535663410560174
# RMSE for food item 107: 6.718843437888484
# RMSE for food item 108: 0.6813851438692469
# RMSE for food item 109: 0.9063269671749657
# RMSE for food item 110: 3.053101467594644
# RMSE for food item 111: 2.3679406363215394
# RMSE for food item 112: 1.4880476182856899
# RMSE for food item 113: 1.6146649364939023
# RMSE for food item 114: 2.1547290184283368
# RMSE for food item 115: 8.645808232895291
# RMSE for food item 116: 2.3754698783308417
# RMSE for food item 117: 0.8864052604279183
# RMSE for food item 118: 20.102416343741933
# RMSE for food item 119: 2.712405363721075
# RMSE for food item 120: 1.1019463300386794
# RMSE for food item 121: 0.4629100498862757
# RMSE for food item 122: 3.7654443865992
# RMSE for food item 123: 0.5976143046671968
# RMSE for food item 124: 2.32992949004287
# RMSE for food item 125: 1.118033988749895
# RMSE for food item 126: 0.9063269671749657
# RMSE for food item 127: 1.14953406710222
# RMSE for food item 128: 1.647508942095828
# RMSE for food item 129: 1.880349511584026
# RMSE for food item 130: 1.6583123951777
# RMSE for food item 131: 3.973123995763823
# RMSE for food item 132: 4.735881272643079
# RMSE for food item 133: 5.815619362667107
# RMSE for food item 134: 5.615666860285988
# RMSE for food item 135: 0.6267831705280087
# RMSE for food item 136: 1.7728105208558367
# RMSE for food item 137: 0.9258200997725514
# RMSE for food item 138: 1.0690449676496976
# RMSE for food item 139: 0.6546536707079771
# RMSE for food item 140: 0.8017837257372732
# RMSE for food item 141: 1.164964745021435
# RMSE for food item 142: 1.2535663410560174
# RMSE for food item 143: 0.8451542547285166
# RMSE for food item 144: 3.3964266937053544
# RMSE for food item 145: 3.7129118338191502
# RMSE for food item 146: 1.9820624179302297
# RMSE for food item 147: 0.8660254037844386
# RMSE for food item 148: 14.642160262162722
# RMSE for food item 149: 4.873397172404482
# RMSE for food item 150: 1.5811388300841898
# RMSE for food item 151: 1.6903085094570331
# RMSE for food item 152: 8.41766849294642
# RMSE for food item 153: 1.0177004891982149
# RMSE for food item 154: 1.9910514092523364
# RMSE for food item 155: 1.5698043554168508
# RMSE for food item 156: 0.823754471047914
# RMSE for food item 157: 0.8451542547285166
# RMSE for food item 158: 0.5976143046671968
# RMSE for food item 159: 0.6546536707079771
# RMSE for food item 160: 0.8864052604279183
# RMSE for food item 161: 1.2817398889233114
# RMSE for food item 162: 0.823754471047914
# RMSE for food item 163: 0.5345224838248488
# RMSE for food item 164: 2.052872551885702
# RMSE for food item 165: 1.1338934190276817
# RMSE for food item 166: 0.9063269671749657
# RMSE for food item 167: 1.4267845968170128
# RMSE for food item 168: 0.5669467095138409
# RMSE for food item 169: 0.2672612419124244
# RMSE for food item 170: 2.017778127403648
# RMSE for food item 171: 0.5669467095138409
# RMSE for food item 172: 1.3228756555322954
# RMSE for food item 173: 0.2672612419124244
# RMSE for food item 174: 1.2100767390069582
# RMSE for food item 175: 0.5669467095138409
# RMSE for food item 176: 2.29906813420444
# RMSE for food item 177: 0.7319250547113999
# RMSE for food item 178: 0.5
# RMSE for food item 179: 2.611786471254603
# RMSE for food item 180: 0.9819805060619657
# RMSE for food item 181: 1.0522085616183026
# RMSE for food item 182: 1.3627702877384937
# RMSE for food item 183: 2.8598201741668006
# RMSE for food item 184: 1.224744871391589
# RMSE for food item 185: 0.5976143046671968
# RMSE for food item 186: 0.4629100498862757
# RMSE for food item 187: 0.4225771273642583
# RMSE for food item 188: 2.306822180279306
# RMSE for food item 189: 1.5698043554168508
# RMSE for food item 190: 0.9636241116594315
# RMSE for food item 191: 0.6813851438692469
# RMSE for food item 192: 0.7559289460184544
# RMSE for food item 193: 4.044396476254876
# RMSE for food item 194: 0.7791937224739796
# RMSE for food item 195: 0.7791937224739796
# RMSE for food item 196: 0.7071067811865476
# RMSE for food item 197: 0.7319250547113999
# RMSE for food item 198: 1.5923926292577109
# RMSE for food item 199: 2.4784787961282104
# RMSE for food item 200: 15.036859474542643
# RMSE for food item 201: 1.546886273407694
# RMSE for food item 202: 0.7559289460184544
# RMSE for food item 203: 2.104417123236605
# RMSE for food item 204: 1.4880476182856899
# RMSE for food item 205: 0.8660254037844386
# RMSE for food item 206: 1.535298947157477
# RMSE for food item 207: 0.823754471047914
# RMSE for food item 208: 0.5345224838248488
# RMSE for food item 209: 1.439245834257849
# RMSE for food item 210: 0.823754471047914
# RMSE for food item 211: 2.6186146828319083
# RMSE for food item 212: 1.6366341767699428
# RMSE for food item 213: 1.5118578920369088
# RMSE for food item 214: 0.5669467095138409
# RMSE for food item 215: 0.9819805060619657
# RMSE for food item 216: 0.9819805060619657
# RMSE for food item 217: 1.5698043554168508
# RMSE for food item 218: 0.2672612419124244
# RMSE for food item 219: 1.0177004891982149
# RMSE for food item 220: 0.7559289460184544
# RMSE for food item 221: 0.5
# RMSE for food item 222: 1.546886273407694
# RMSE for food item 223: 1.118033988749895
# RMSE for food item 224: 5.791002873916942
# RMSE for food item 225: 5.4050241178264615
# RMSE for food item 226: 3.2732683535398857
# RMSE for food item 227: 0.9636241116594315
# RMSE for food item 228: 1.9548474547720014
# RMSE for food item 229: 3.3541019662496847
# RMSE for food item 230: 1.6903085094570331
# RMSE for food item 231: 4.280353790451039
# RMSE for food item 232: 13.047988350699889
# RMSE for food item 233: 0.4629100498862757
# RMSE for food item 234: 1.3887301496588271
# RMSE for food item 235: 9.200155278192709
# RMSE for food item 236: 2.052872551885702
# RMSE for food item 237: 1.1019463300386794
# RMSE for food item 238: 1.1019463300386794
# RMSE for food item 239: 1.164964745021435
# RMSE for food item 240: 0.7319250547113999
# RMSE for food item 241: 2.0
# RMSE for food item 242: 0.4225771273642583
# RMSE for food item 243: 4.066412950711509
# RMSE for food item 244: 1.5
# RMSE for food item 245: 0.9063269671749657
# RMSE for food item 246: 0.823754471047914
# RMSE for food item 247: 1.917960226013936
# RMSE for food item 248: 1.3363062095621219
# RMSE for food item 249: 1.3363062095621219
# RMSE for food item 250: 20.81637404956561
# RMSE for food item 251: 1.2817398889233114
# RMSE for food item 252: 1.2392393980641052
# RMSE for food item 253: 0.8660254037844386
# RMSE for food item 254: 0.32732683535398854
# RMSE for food item 255: 1.546886273407694
# RMSE for food item 256: 2.53546276418555
# RMSE for food item 257: 2.1712405933672376
# RMSE for food item 258: 0.1889822365046136
# RMSE for food item 259: 1.2535663410560174
# RMSE for food item 260: 0.7071067811865476
# RMSE for food item 261: 4.566962103755937
# RMSE for food item 262: 0.5976143046671968
# RMSE for food item 263: 1.2817398889233114
# RMSE for food item 264: 1.14953406710222
# RMSE for food item 265: 1.3758114488755873
# RMSE for food item 266: 0.8864052604279183
# RMSE for food item 267: 0.9636241116594315
# RMSE for food item 268: 0.4225771273642583
# RMSE for food item 269: 1.349603116263656
# RMSE for food item 270: 1.0856202966836188
# RMSE for food item 271: 0.9063269671749657
# RMSE for food item 272: 0.8451542547285166
# RMSE for food item 273: 1.1019463300386794
# RMSE for food item 274: 1.7728105208558367
# RMSE for food item 275: 1.6366341767699428
# RMSE for food item 276: 2.017778127403648
# RMSE for food item 277: 0.4225771273642583
# RMSE for food item 278: 0.7071067811865476
# RMSE for food item 279: 2.878491668515698
# RMSE for food item 280: 10.097736662950055
# RMSE for food item 281: 1.0
# RMSE for food item 282: 0.7071067811865476
# RMSE for food item 283: 1.1952286093343936
# RMSE for food item 284: 0.9063269671749657
# RMSE for food item 285: 0.8017837257372732
# RMSE for food item 286: 3.311236281856931
# RMSE for food item 287: 0.4629100498862757
# RMSE for food item 288: 2.23606797749979
# RMSE for food item 289: 1.3758114488755873
# RMSE for food item 290: 2.1464256001881026
# RMSE for food item 291: 0.7071067811865476
# RMSE for food item 292: 0.944911182523068
# RMSE for food item 293: 15.15279323613778
# RMSE for food item 294: 0.5
# RMSE for food item 295: 0.823754471047914
# RMSE for food item 296: 0.32732683535398854
# RMSE for food item 297: 1.558387444947959
# RMSE for food item 298: 2.3222526010012654
# RMSE for food item 299: 0.8660254037844386
# RMSE for food item 300: 2.3222526010012654
# RMSE for food item 301: 0.8017837257372732
# RMSE for food item 302: 1.1801936887041646
# RMSE for food item 303: 1.4516001023501126
# RMSE for food item 304: 2.3375811674219387
# RMSE for food item 305: 2.0
# RMSE for food item 306: 0.8864052604279183
# RMSE for food item 307: 0.5669467095138409
# RMSE for food item 308: 0.9063269671749657
# RMSE for food item 309: 0.8451542547285166
# RMSE for food item 310: 0.32732683535398854
# RMSE for food item 311: 7.601691541079149
# RMSE for food item 312: 0.5669467095138409
# RMSE for food item 313: 0.4225771273642583
# RMSE for food item 314: 0.6267831705280087
# RMSE for food item 315: 2.0615528128088303
# RMSE for food item 316: 3.3964266937053544
# RMSE for food item 317: 14.545495129813512
# RMSE for food item 318: 0.5669467095138409
# RMSE for food item 319: 4.836616290637199
# RMSE for food item 320: 1.349603116263656
# RMSE for food item 321: 0.7071067811865476
# RMSE for food item 322: 2.23606797749979
# RMSE for food item 323: 0.5345224838248488
# RMSE for food item 324: 1.742330131092924
# RMSE for food item 325: 3.2015621187164243
# RMSE for food item 326: 0.1889822365046136
# RMSE for food item 327: 8.79122939558025
# RMSE for food item 328: 1.8516401995451028
# RMSE for food item 329: 1.439245834257849
# RMSE for food item 330: 1.6366341767699428
# RMSE for food item 331: 10.273057689204043
# RMSE for food item 332: 0.7791937224739796
# RMSE for food item 333: 1.2817398889233114
# RMSE for food item 334: 0.8017837257372732
# RMSE for food item 335: 0.5
# RMSE for food item 336: 1.164964745021435
# RMSE for food item 337: 2.3145502494313788
# RMSE for food item 338: 1.3093073414159542
# RMSE for food item 339: 1.0
# RMSE for food item 340: 2.5424959615082408
# RMSE for food item 341: 0.32732683535398854
# RMSE for food item 342: 1.475998451412273
# RMSE for food item 343: 0.8451542547285166
# RMSE for food item 344: 2.2519832529192065
# RMSE for food item 345: 1.6366341767699428
# RMSE for food item 346: 5.30161700400386
# RMSE for food item 347: 7.321689890806825
# RMSE for food item 348: 0.5
# RMSE for food item 349: 2.1213203435596424
# RMSE for food item 350: 1.0177004891982149
# RMSE for food item 351: 1.5923926292577109
# RMSE for food item 352: 0.7071067811865476
# RMSE for food item 353: 1.535298947157477
# RMSE for food item 354: 0.944911182523068
# RMSE for food item 355: 0.3779644730092272
# RMSE for food item 356: 0.32732683535398854
# RMSE for food item 357: 0.7071067811865476
# RMSE for food item 358: 1.9456912102680337
# RMSE for food item 359: 2.2038926600773587
# RMSE for food item 360: 8.200609733428363
# RMSE for food item 361: 5.812548002873979
# RMSE for food item 362: 0.5345224838248488
# RMSE for food item 363: 0.5669467095138409
# RMSE for food item 364: 0.9063269671749657
# RMSE for food item 365: 2.23606797749979
# RMSE for food item 366: 2.53546276418555
# RMSE for food item 367: 1.4516001023501126
# RMSE for food item 368: 9.9498743710662
# RMSE for food item 369: 1.7008401285415224
# RMSE for food item 370: 3.6203788278497675
# RMSE for food item 371: 0.7559289460184544
# RMSE for food item 372: 0.5976143046671968
# RMSE for food item 373: 0.6267831705280087
# RMSE for food item 374: 11.453321414706366
# RMSE for food item 375: 11.76860229593982
# RMSE for food item 376: 0.8451542547285166
# RMSE for food item 377: 1.6035674514745464
# RMSE for food item 378: 0.6546536707079771
# RMSE for food item 379: 3.035504194410825
# RMSE for food item 380: 2.1128856368212916
# RMSE for food item 381: 1.8612591743993405
# RMSE for food item 382: 0.9063269671749657
# RMSE for food item 383: 0.9063269671749657
# RMSE for food item 384: 0.8660254037844386
# RMSE for food item 385: 1.0
# RMSE for food item 386: 1.1338934190276817
# RMSE for food item 387: 6.190430402761069
# RMSE for food item 388: 0.9636241116594315
# RMSE for food item 389: 0.8451542547285166
# RMSE for food item 390: 0.8864052604279183
# RMSE for food item 391: 3.8913824205360674
# RMSE for food item 392: 0.5976143046671968
# RMSE for food item 393: 0.8451542547285166
# RMSE for food item 394: 0.5
# RMSE for food item 395: 0.5669467095138409
# RMSE for food item 396: 0.944911182523068
# RMSE for food item 397: 3.600595188893874
# RMSE for food item 398: 0.7791937224739796
# RMSE for food item 399: 0.7559289460184544
# RMSE for food item 400: 0.7559289460184544
# RMSE for food item 401: 1.6690459207925603
# RMSE for food item 402: 14.656787798539916
# RMSE for food item 403: 0.7319250547113999
# RMSE for food item 404: 4.105745103771404
# RMSE for food item 405: 1.14953406710222
# RMSE for food item 406: 0.2672612419124244
# RMSE for food item 407: 0.7791937224739796
# RMSE for food item 408: 0.6813851438692469
# RMSE for food item 409: 1.14953406710222
# RMSE for food item 410: 5.870629073130555
# RMSE for food item 411: 3.116774889895918
# RMSE for food item 412: 1.0
# RMSE for food item 413: 1.3228756555322954
# RMSE for food item 414: 0.8451542547285166
# RMSE for food item 415: 0.7319250547113999
# RMSE for food item 416: 1.2392393980641052
# RMSE for food item 417: 1.535298947157477
# RMSE for food item 418: 1.4638501094227998
# RMSE for food item 419: 0.4225771273642583
# RMSE for food item 420: 1.917960226013936
# RMSE for food item 421: 1.14953406710222
# RMSE for food item 422: 0.8660254037844386
# RMSE for food item 423: 0.9258200997725514
# RMSE for food item 424: 0.7791937224739796
# RMSE for food item 425: 0.7791937224739796
# RMSE for food item 426: 1.0
# RMSE for food item 427: 1.118033988749895
# RMSE for food item 428: 0.7319250547113999
# RMSE for food item 429: 2.0788046015507495
# RMSE for food item 430: 2.4053511772118195
# RMSE for food item 431: 0.944911182523068
# RMSE for food item 432: 0.9819805060619657
# RMSE for food item 433: 1.8027756377319946
# RMSE for food item 434: 0.5976143046671968
# RMSE for food item 435: 1.9456912102680337
# RMSE for food item 436: 2.49284690951645
# RMSE for food item 437: 1.3758114488755873
# RMSE for food item 438: 0.5976143046671968
# RMSE for food item 439: 5.60930349636082
# RMSE for food item 440: 0.8451542547285166
# RMSE for food item 441: 0.7559289460184544
# RMSE for food item 442: 14.896068512961973
# RMSE for food item 443: 0.7791937224739796
# RMSE for food item 444: 2.5495097567963922
# RMSE for food item 445: 1.3093073414159542
# RMSE for food item 446: 1.9456912102680337
# RMSE for food item 447: 1.546886273407694
# RMSE for food item 448: 1.4015297764534702
# RMSE for food item 449: 9.507515823960386
# RMSE for food item 450: 0.6546536707079771
# RMSE for food item 451: 0.3779644730092272
# RMSE for food item 452: 7.545102479659997
# RMSE for food item 453: 11.628167771161788
# RMSE for food item 454: 0.6813851438692469
# RMSE for food item 455: 0.944911182523068
# RMSE for food item 456: 3.6839419880650364
# RMSE for food item 457: 2.659215781283755
# RMSE for food item 458: 1.3093073414159542
# RMSE for food item 459: 4.0
# RMSE for food item 460: 10.554281460282228
# RMSE for food item 461: 2.187627547301936
# RMSE for food item 462: 0.9819805060619657
# RMSE for food item 463: 0.7319250547113999
# RMSE for food item 464: 0.8864052604279183
# RMSE for food item 465: 0.8864052604279183
# RMSE for food item 466: 1.9086270308410553
# RMSE for food item 467: 2.0701966780270626
# RMSE for food item 468: 1.118033988749895
# RMSE for food item 469: 0.9063269671749657
# RMSE for food item 470: 0.5976143046671968
# RMSE for food item 471: 3.4226138716316967
# RMSE for food item 472: 4.590362575159894
# RMSE for food item 473: 1.9730324738475904
# RMSE for food item 474: 3.122498999199199
# RMSE for food item 475: 3.770183777256185
# RMSE for food item 476: 1.8516401995451028
# RMSE for food item 477: 1.5923926292577109
# RMSE for food item 478: 0.8451542547285166
# RMSE for food item 479: 0.7071067811865476
# RMSE for food item 480: 0.944911182523068
# RMSE for food item 481: 0.944911182523068
# RMSE for food item 482: 1.0522085616183026
# RMSE for food item 483: 1.118033988749895
# RMSE for food item 484: 0.5669467095138409
# RMSE for food item 485: 2.8722813232690143
# RMSE for food item 486: 1.917960226013936
# RMSE for food item 487: 1.6583123951777
# RMSE for food item 488: 1.0856202966836188
# RMSE for food item 489: 4.613644360558612
# RMSE for food item 490: 0.8864052604279183
# RMSE for food item 491: 0.5669467095138409
# RMSE for food item 492: 0.5
# RMSE for food item 493: 2.1957751641341994
# RMSE for food item 494: 1.6583123951777
# RMSE for food item 495: 0.5669467095138409
# RMSE for food item 496: 10.496598088360411
# RMSE for food item 497: 9.713760490002976
# RMSE for food item 498: 1.0177004891982149
# RMSE for food item 499: 13.794408805226642
# RMSE for food item 500: 1.8612591743993405
# RMSE for food item 501: 5.049752469181039
# RMSE for food item 502: 1.5698043554168508
# RMSE for food item 503: 1.1801936887041646
# RMSE for food item 504: 0.6813851438692469
# RMSE for food item 505: 0.3779644730092272
# RMSE for food item 506: 1.5236235005501102
# RMSE for food item 507: 0.7319250547113999
# RMSE for food item 508: 0.9258200997725514
# RMSE for food item 509: 4.547369726399144
# RMSE for food item 510: 0.3779644730092272
# RMSE for food item 511: 1.0350983390135313
# RMSE for food item 512: 1.5118578920369088
# RMSE for food item 513: 1.14953406710222
# RMSE for food item 514: 7.511895328648518
# RMSE for food item 515: 0.3779644730092272
# RMSE for food item 516: 0.9063269671749657
# RMSE for food item 517: 1.8027756377319946
# RMSE for food item 518: 1.439245834257849
# RMSE for food item 519: 0.6267831705280087
# RMSE for food item 520: 0.32732683535398854
# RMSE for food item 521: 2.345207879911715
# RMSE for food item 522: 6.96162953009464
# RMSE for food item 523: 1.14953406710222
# RMSE for food item 524: 2.958039891549808
# RMSE for food item 525: 0.5976143046671968
# RMSE for food item 526: 0.7319250547113999
# RMSE for food item 527: 1.0522085616183026
# RMSE for food item 528: 4.531634835874828
# RMSE for food item 529: 1.0522085616183026
# RMSE for food item 530: 1.2100767390069582
# RMSE for food item 531: 1.14953406710222
# RMSE for food item 532: 1.8322507626258087
# RMSE for food item 533: 0.9063269671749657
# RMSE for food item 534: 1.1019463300386794
# RMSE for food item 535: 1.267731382092775
# RMSE for food item 536: 1.546886273407694
# RMSE for food item 537: 0.32732683535398854
# RMSE for food item 538: 2.7838821814150108
# RMSE for food item 539: 13.759412362867412
# RMSE for food item 540: 0.1889822365046136
# RMSE for food item 541: 0.3779644730092272
# RMSE for food item 542: 0.823754471047914
# RMSE for food item 543: 1.6903085094570331
# RMSE for food item 544: 4.153311931459037
# RMSE for food item 545: 7.250615737399726
# RMSE for food item 546: 0.7071067811865476
# RMSE for food item 547: 0.7791937224739796
# RMSE for food item 548: 0.5976143046671968
# RMSE for food item 549: 1.439245834257849
# RMSE for food item 550: 1.118033988749895
# RMSE for food item 551: 0.5669467095138409
# RMSE for food item 552: 0.5976143046671968
# RMSE for food item 553: 17.20361257742936
# RMSE for food item 554: 0.4225771273642583
# RMSE for food item 555: 2.712405363721075
# RMSE for food item 556: 0.7071067811865476
# RMSE for food item 557: 0.9063269671749657
# RMSE for food item 558: 1.3363062095621219
# RMSE for food item 559: 1.9730324738475904
# RMSE for food item 560: 1.9910514092523364
# RMSE for food item 561: 1.1801936887041646
# RMSE for food item 562: 0.9819805060619657
# RMSE for food item 563: 2.815771906346718
# RMSE for food item 564: 3.017804310611087
# RMSE for food item 565: 0.5
# RMSE for food item 566: 2.179449471770337
# RMSE for food item 567: 0.9819805060619657
# RMSE for food item 568: 4.101393491415884
# RMSE for food item 569: 1.0522085616183026
# RMSE for food item 570: 5.615666860285988
# RMSE for food item 571: 1.8322507626258087
# RMSE for food item 572: 4.33836703973149
# RMSE for food item 573: 0.4629100498862757
# RMSE for food item 574: 0.7319250547113999
# RMSE for food item 575: 0.9063269671749657
# RMSE for food item 576: 2.988071523335984
# RMSE for food item 577: 0.8451542547285166
# RMSE for food item 578: 18.114713830001765
# RMSE for food item 579: 0.4629100498862757
# RMSE for food item 580: 0.8451542547285166
# RMSE for food item 581: 1.0856202966836188
# RMSE for food item 582: 1.7217101133134214
# RMSE for food item 583: 1.9639610121239315
# RMSE for food item 584: 16.025649084247057
# RMSE for food item 585: 6.76915272182779
# RMSE for food item 586: 1.1019463300386794
# RMSE for food item 587: 2.026608708444444
# RMSE for food item 588: 1.9086270308410553
# RMSE for food item 589: 1.3758114488755873
# RMSE for food item 590: 1.3758114488755873
# RMSE for food item 591: 1.2100767390069582
# RMSE for food item 592: 4.20458932936041
# RMSE for food item 593: 0.9636241116594315
# RMSE for food item 594: 1.5811388300841898
# RMSE for food item 595: 0.2672612419124244
# RMSE for food item 596: 3.525417908358019
# RMSE for food item 597: 1.118033988749895
# RMSE for food item 598: 0.8017837257372732
# RMSE for food item 599: 0.3779644730092272
# RMSE for food item 600: 1.4516001023501126
# RMSE for food item 601: 2.0701966780270626
# RMSE for food item 602: 1.0350983390135313
# RMSE for food item 603: 1.8224786888818678
# RMSE for food item 604: 1.2535663410560174
# RMSE for food item 605: 8.4070548605663
# RMSE for food item 606: 1.1952286093343936
# RMSE for food item 607: 1.0856202966836188
# RMSE for food item 608: 1.0690449676496976
# RMSE for food item 609: 1.558387444947959
# RMSE for food item 610: 0.3779644730092272
# RMSE for food item 611: 0.32732683535398854
# RMSE for food item 612: 3.789082059964241
# RMSE for food item 613: 1.4516001023501126
# RMSE for food item 614: 3.0764079239082895
# RMSE for food item 615: 1.6903085094570331
# RMSE for food item 616: 2.7774602993176543
# RMSE for food item 617: 0.4225771273642583
# RMSE for food item 618: 1.2100767390069582
# RMSE for food item 619: 1.6583123951777
# RMSE for food item 620: 0.6267831705280087
# RMSE for food item 621: 0.32732683535398854
# RMSE for food item 622: 1.5698043554168508
# RMSE for food item 623: 0.4629100498862757
# RMSE for food item 624: 0.6813851438692469
# RMSE for food item 625: 0.7319250547113999
# RMSE for food item 626: 2.822106609305487
# RMSE for food item 627: 0.7319250547113999
# RMSE for food item 628: 0.4225771273642583
# RMSE for food item 629: 0.5
# RMSE for food item 630: 0.9636241116594315
# RMSE for food item 631: 0.4629100498862757
# RMSE for food item 632: 1.349603116263656
# RMSE for food item 633: 20.338211748894178
# RMSE for food item 634: 1.7627089541790095
# RMSE for food item 635: 0.3779644730092272
# RMSE for food item 636: 1.118033988749895
# RMSE for food item 637: 1.2535663410560174
# RMSE for food item 638: 1.6035674514745464
# RMSE for food item 639: 0.5
# RMSE for food item 640: 0.823754471047914
# RMSE for food item 641: 2.5424959615082408
# RMSE for food item 642: 2.138089935299395
# RMSE for food item 643: 0.7319250547113999
# RMSE for food item 644: 1.8992479714726187
# RMSE for food item 645: 1.6903085094570331
# RMSE for food item 646: 2.0959143930173156
# RMSE for food item 647: 0.5976143046671968
# RMSE for food item 648: 1.1338934190276817
# RMSE for food item 649: 1.9639610121239315
# RMSE for food item 650: 3.8312623805439676
# RMSE for food item 651: 1.0177004891982149
# RMSE for food item 652: 4.6675169293441545
# RMSE for food item 653: 1.2535663410560174
# RMSE for food item 654: 1.6366341767699428
# RMSE for food item 655: 1.8027756377319946
# RMSE for food item 656: 0.5976143046671968
# RMSE for food item 657: 1.0350983390135313
# RMSE for food item 658: 8.137216091163225
# RMSE for food item 659: 2.866057521105554
# RMSE for food item 660: 1.6583123951777
# RMSE for food item 661: 1.8612591743993405
# RMSE for food item 662: 4.5197977198732495
# RMSE for food item 663: 1.3228756555322954
# RMSE for food item 664: 0.9636241116594315
# RMSE for food item 665: 1.4638501094227998
# RMSE for food item 666: 1.889822365046136
# RMSE for food item 667: 2.32992949004287
# RMSE for food item 668: 0.6267831705280087
# RMSE for food item 669: 4.996427295006474
# RMSE for food item 670: 4.898979485566356
# RMSE for food item 671: 1.0522085616183026
# RMSE for food item 672: 1.546886273407694
# RMSE for food item 673: 1.5811388300841898
# RMSE for food item 674: 0.5976143046671968
# RMSE for food item 675: 0.8451542547285166
# RMSE for food item 676: 1.3758114488755873
# RMSE for food item 677: 2.3679406363215394
# RMSE for food item 678: 0.32732683535398854
# RMSE for food item 679: 11.629703349613008
# RMSE for food item 680: 3.7984959429452374
# RMSE for food item 681: 2.3145502494313788
# RMSE for food item 682: 1.7828548534783835
# RMSE for food item 683: 0.7791937224739796
# RMSE for food item 684: 0.5
# RMSE for food item 685: 0.9258200997725514
# RMSE for food item 686: 4.5197977198732495
# RMSE for food item 687: 0.6813851438692469
# RMSE for food item 688: 0.7559289460184544
# RMSE for food item 689: 0.5669467095138409
# RMSE for food item 690: 1.9910514092523364
# RMSE for food item 691: 0.7319250547113999
# RMSE for food item 692: 9.604686356149273
# RMSE for food item 693: 3.011881234615431
# RMSE for food item 694: 0.7319250547113999
# RMSE for food item 695: 3.3434370681338432
# RMSE for food item 696: 1.8516401995451028
# RMSE for food item 697: 1.2100767390069582
# RMSE for food item 698: 1.0856202966836188
# RMSE for food item 699: 4.69041575982343
# RMSE for food item 700: 1.14953406710222
# RMSE for food item 701: 2.9459415181858972
# RMSE for food item 702: 0.5345224838248488
# RMSE for food item 703: 2.692582403567252
# RMSE for food item 704: 2.382975331087468
# RMSE for food item 705: 0.9258200997725514
# RMSE for food item 706: 1.3228756555322954
# RMSE for food item 707: 0.5
# RMSE for food item 708: 10.513596638910697
# RMSE for food item 709: 1.0177004891982149
# RMSE for food item 710: 0.1889822365046136
# RMSE for food item 711: 8.364465656232065
# RMSE for food item 712: 1.2392393980641052
# RMSE for food item 713: 0.7559289460184544
# RMSE for food item 714: 1.3627702877384937
# RMSE for food item 715: 0.1889822365046136
# RMSE for food item 716: 1.4516001023501126
# RMSE for food item 717: 0.6546536707079771
# RMSE for food item 718: 0.9258200997725514
# RMSE for food item 719: 0.7791937224739796
# RMSE for food item 720: 7.406560798180411
# RMSE for food item 721: 0.7559289460184544
# RMSE for food item 722: 0.8017837257372732
# RMSE for food item 723: 0.32732683535398854
# RMSE for food item 724: 2.5704363164923687
# RMSE for food item 725: 1.8419709940325182
# RMSE for food item 726: 1.164964745021435
# RMSE for food item 727: 0.944911182523068
# RMSE for food item 728: 1.4638501094227998
# RMSE for food item 729: 1.9086270308410553
# RMSE for food item 730: 2.2834810518779687
# RMSE for food item 731: 0.7071067811865476
# RMSE for food item 732: 0.2672612419124244
# RMSE for food item 733: 0.3779644730092272
# RMSE for food item 734: 2.220038609702865
# RMSE for food item 735: 3.755947664324259
# RMSE for food item 736: 4.191828786034631
# RMSE for food item 737: 1.1019463300386794
# RMSE for food item 738: 0.8017837257372732
# RMSE for food item 739: 3.7080992435478315
# RMSE for food item 740: 0.6813851438692469
# RMSE for food item 741: 1.5698043554168508
# RMSE for food item 742: 4.678980352903519
# RMSE for food item 743: 1.164964745021435
# RMSE for food item 744: 0.9636241116594315
# RMSE for food item 745: 2.1464256001881026
# RMSE for food item 746: 1.558387444947959
# RMSE for food item 747: 11.606648341114058
# RMSE for food item 748: 2.1128856368212916
# RMSE for food item 749: 0.5976143046671968
# RMSE for food item 750: 2.4201534780139164
# RMSE for food item 751: 3.070597894314954
# RMSE for food item 752: 4.648348401006841
# RMSE for food item 753: 0.1889822365046136
# RMSE for food item 754: 1.1338934190276817
# RMSE for food item 755: 2.3754698783308417
# RMSE for food item 756: 1.2100767390069582
# RMSE for food item 757: 0.5345224838248488
# RMSE for food item 758: 0.8660254037844386
# RMSE for food item 759: 5.710266443620897
# RMSE for food item 760: 0.8864052604279183
# RMSE for food item 761: 0.4629100498862757
# RMSE for food item 762: 9.980337812776822
# RMSE for food item 763: 1.4142135623730951
# RMSE for food item 764: 2.3528098702858005
# RMSE for food item 765: 0.8660254037844386
# RMSE for food item 766: 0.5669467095138409
# RMSE for food item 767: 13.286674312472414
# RMSE for food item 768: 0.5976143046671968
# RMSE for food item 769: 0.9636241116594315
# RMSE for food item 770: 0.6267831705280087
# RMSE for food item 771: 1.0177004891982149
# RMSE for food item 772: 1.0690449676496976
# RMSE for food item 773: 0.7071067811865476
# RMSE for food item 774: 0.5345224838248488
# RMSE for food item 775: 1.1801936887041646
# RMSE for food item 776: 1.4638501094227998
# RMSE for food item 777: 5.697743914417856
# RMSE for food item 778: 1.8126539343499315
# RMSE for food item 779: 0.2672612419124244
# RMSE for food item 780: 7.15392000434527
# RMSE for food item 781: 1.6583123951777
# RMSE for food item 782: 2.921594476602509
# RMSE for food item 783: 2.0441554316077406
# RMSE for food item 784: 2.659215781283755
# RMSE for food item 785: 0.8660254037844386
# RMSE for food item 786: 1.5923926292577109
# RMSE for food item 787: 2.412763679150648
# RMSE for food item 788: 0.6267831705280087
# RMSE for food item 789: 1.0522085616183026
# RMSE for food item 790: 1.4015297764534702
# RMSE for food item 791: 0.2672612419124244
# RMSE for food item 792: 1.0856202966836188
# RMSE for food item 793: 0.4225771273642583
# RMSE for food item 794: 0.3779644730092272
# RMSE for food item 795: 10.35615758860399
# RMSE for food item 796: 2.8722813232690143
# RMSE for food item 797: 0.5669467095138409
# RMSE for food item 798: 1.4880476182856899
# RMSE for food item 799: 15.491933384829668
# RMSE for food item 800: 1.6690459207925603
# RMSE for food item 801: 0.8451542547285166
# RMSE for food item 802: 1.8708286933869707
# RMSE for food item 803: 20.057951754140515
# RMSE for food item 804: 4.403732183370957
# RMSE for food item 805: 0.4629100498862757
# RMSE for food item 806: 9.571162043197413
# RMSE for food item 807: 0.9819805060619657
# RMSE for food item 808: 1.5698043554168508
# RMSE for food item 809: 1.9820624179302297
# RMSE for food item 810: 0.5669467095138409
# RMSE for food item 811: 4.713203338949606
# RMSE for food item 812: 0.1889822365046136
# RMSE for food item 813: 1.2955969390869324
# RMSE for food item 814: 1.14953406710222
# RMSE for food item 815: 1.5811388300841898
# RMSE for food item 816: 0.6813851438692469
# RMSE for food item 817: 2.220038609702865
# RMSE for food item 818: 0.7791937224739796
# RMSE for food item 819: 0.32732683535398854
# RMSE for food item 820: 1.679710859472121
# RMSE for food item 821: 2.104417123236605
# RMSE for food item 822: 2.0
# Total RMSE: 1862.9340650935105
# Average RMSE per item: 2.263589386504873
